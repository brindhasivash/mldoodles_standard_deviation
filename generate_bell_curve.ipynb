# %% [markdown]
# # Generate bell curve

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
x = np.arange(-5, 5, 0.01)
y = norm.pdf(x, 0, 1)
plt.plot(x, y)
plt.show()
